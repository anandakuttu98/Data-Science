# %% [markdown]
# ### 5. Analysing India's Imports from Afghanistan

# %%
# Importing all the required tools we need
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %matplotlib inline

# %%
# Importing the data
import_data = pd.read_excel("Afghanistan data1.xlsx", sheet_name = "Sheet11", index_col = 0)
import_data.to_csv("Afghanistan data1.csv", encoding = 'utf-8', index = False)
import_data
# Out:
#                                                    Unnamed: 1  \
# Country:  AFGHANISTAN
# * ITC HS Code of the Commodity is either droppe...        NaN
# NaN                                                       NaN
# S.No.                                                  HSCode
# 1                                                           4
# 2                                                           5
# 3                                                           6
# 4                                                           7
# 5                                                           8
# 6                                                           9
# 7                                                          11
# 8                                                          12
# 10                                                         13
# 11                                                         20
# 12                                                         22
# ...

# %%
# Reindexing Columns and Rows
import_data.columns = import_data.iloc[2]
import_data = import_data.iloc[3:,].reindex()
import_data
# Out:
# S.No.                 HSCode  \
# Country:  AFGHANISTAN
# 1                          4
# 2                          5
# 3                          6
# 4                          7
# 5                          8
# 6                          9
# 7                         11
# 8                         12
# 10                        13
# 11                        20
# 12                        22
# 13                        25
# 14                        27
# 15                        28
# 16                        30
# 17                        33
# 18                        38
# 19                        39
# 20                        40
# 21                        41
# 22                        42
# 23                        46
# 24                        49
# 25                        51
# 26                        52
# 27                        54
# 28                        56
# 29                        57
# 30                        58
# 31                        60
# ...

# %%
import_data.set_index(import_data.iloc[:, 1].values, inplace = True)
import_data.drop(["HSCode", "Commodity"], axis = 1, inplace = True)
import_data
# Out:
# S.No.                                              2016-2017 2017-2018  \
# DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDIB...       NaN       NaN
# PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE SPECIF...       NaN       NaN
# LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND T...       NaN       NaN
# EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.        12.32     10.74
# EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR ...    167.24    274.79
# COFFEE, TEA, MATE AND SPICES.                          26.06     33.66
# PRODUCTS OF THE MILLING INDUSTRY; MALT; STARCHE...       NaN       NaN
# OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEEDS...      6.69       8.9
# LAC; GUMS, RESINS AND OTHER VEGETABLE SAPS AND ...     80.05    103.33
# PREPARATIONS OF VEGETABLES, FRUIT, NUTS OR OTHE...       0.1      2.01
# BEVERAGES, SPIRITS AND VINEGAR.                          NaN       NaN
# SALT; SULPHUR; EARTHS AND STONE; PLASTERING MAT...      0.08      0.12
# ...

# %%
# Naming the columns and rows
import_data.rename_axis(index= "Commodity", columns = "Years", inplace = True)
import_data
# Out:
# Years                                              2016-2017 2017-2018  \
# Commodity
# DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDIB...       NaN       NaN
# PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE SPECIF...       NaN       NaN
# LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND T...       NaN       NaN
# EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.        12.32     10.74
# EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR ...    167.24    274.79
# COFFEE, TEA, MATE AND SPICES.                          26.06     33.66
# PRODUCTS OF THE MILLING INDUSTRY; MALT; STARCHE...       NaN       NaN
# OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEEDS...      6.69       8.9
# LAC; GUMS, RESINS AND OTHER VEGETABLE SAPS AND ...     80.05    103.33
# PREPARATIONS OF VEGETABLES, FRUIT, NUTS OR OTHE...       0.1      2.01
# BEVERAGES, SPIRITS AND VINEGAR.                          NaN       NaN
# SALT; SULPHUR; EARTHS AND STONE; PLASTERING MAT...      0.08      0.12
# ...

# %%
# Separating the table in two parts based on value and quantity
value_imports = import_data.iloc[:, :9]
quantity_imports = import_data.iloc[:, 9:]
value_imports
# Out:
# Years                                              2016-2017 2017-2018  \
# Commodity
# DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDIB...       NaN       NaN
# PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE SPECIF...       NaN       NaN
# LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND T...       NaN       NaN
# EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.        12.32     10.74
# EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR ...    167.24    274.79
# COFFEE, TEA, MATE AND SPICES.                          26.06     33.66
# PRODUCTS OF THE MILLING INDUSTRY; MALT; STARCHE...       NaN       NaN
# OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEEDS...      6.69       8.9
# LAC; GUMS, RESINS AND OTHER VEGETABLE SAPS AND ...     80.05    103.33
# PREPARATIONS OF VEGETABLES, FRUIT, NUTS OR OTHE...       0.1      2.01
# BEVERAGES, SPIRITS AND VINEGAR.                          NaN       NaN
# SALT; SULPHUR; EARTHS AND STONE; PLASTERING MAT...      0.08      0.12
# ...

# %%
quantity_imports
# Out:
# Years                                              2016-2017 2017-2018  \
# Commodity
# DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDIB...       NaN       NaN
# PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE SPECIF...       NaN       NaN
# LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND T...       NaN       NaN
# EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.     12804.76     11967
# EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR ...  32400.06  45205.72
# COFFEE, TEA, MATE AND SPICES.                        2778.02   3264.39
# PRODUCTS OF THE MILLING INDUSTRY; MALT; STARCHE...       NaN      0.49
# OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEEDS...   4588.66   5092.03
# LAC; GUMS, RESINS AND OTHER VEGETABLE SAPS AND ...    996.18   1200.59
# PREPARATIONS OF VEGETABLES, FRUIT, NUTS OR OTHE...      4.46     79.57
# BEVERAGES, SPIRITS AND VINEGAR.                          NaN       NaN
# SALT; SULPHUR; EARTHS AND STONE; PLASTERING MAT...       206    524.17
# ...

# %%
# Removing rows with all Nan values
value_imports.dropna(how = "all", inplace = True)
value_imports
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12096\2050683909.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   value_imports.dropna(how = "all", inplace = True)
# Years                                              2016-2017 2017-2018  \
# Commodity
# DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDIB...       NaN       NaN
# EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.        12.32     10.74
# EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR ...    167.24    274.79
# COFFEE, TEA, MATE AND SPICES.                          26.06     33.66
# PRODUCTS OF THE MILLING INDUSTRY; MALT; STARCHE...       NaN       NaN
# OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEEDS...      6.69       8.9
# LAC; GUMS, RESINS AND OTHER VEGETABLE SAPS AND ...     80.05    103.33
# ...

# %%
quantity_imports.dropna(how = "all", inplace = True)
quantity_imports
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12096\3212071595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quantity_imports.dropna(how = "all", inplace = True)
# Years                                              2016-2017 2017-2018  \
# Commodity
# DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDIB...       NaN       NaN
# LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND T...       NaN       NaN
# EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.     12804.76     11967
# EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR ...  32400.06  45205.72
# COFFEE, TEA, MATE AND SPICES.                        2778.02   3264.39
# PRODUCTS OF THE MILLING INDUSTRY; MALT; STARCHE...       NaN      0.49
# OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEEDS...   4588.66   5092.03
# ...

# %%
len(value_imports)
# Out:
# 39

# %%
len(quantity_imports)
# Out:
# 52

# %%
# Filling the Nan values with 0's
value_imports.fillna(0, inplace = True)
value_imports
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12096\3358880895.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   value_imports.fillna(0, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_12096\3358880895.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   value_imports.fillna(0, inplace = True)
# Years                                               2016-2017  2017-2018  \
# Commodity
# DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDIB...       0.00       0.00
# EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.         12.32      10.74
# ...

# %%
quantity_imports.fillna(0, inplace = True)
quantity_imports
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12096\288223842.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   quantity_imports.fillna(0, inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_12096\288223842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quantity_imports.fillna(0, inplace = True)
# Years                                               2016-2017  2017-2018  \
# Commodity
# DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDIB...       0.00       0.00
# LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND T...       0.00       0.00
# ...

# %%
# Describing the Value of Imports
value_imports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDIBLE PROD. OF ANIMAL ORIGIN, NOT ELSEWHERE SPEC. OR INCLUDED.   to MISCELLANEOUS GOODS.
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   2016-2017           39 non-null     float64
#  1   2017-2018           39 non-null     float64
#  2   2018-2019           39 non-null     float64
#  3   2019-2020           39 non-null     float64
#  4   2020-2021           39 non-null     float64
#  5   2021-2022           39 non-null     float64
#  6   2022-2023           39 non-null     float64
#  7   2023-2024           39 non-null     float64
#  8   2024-2025(Apr-May)  39 non-null     float64
# dtypes: float64(9)
# memory usage: 3.0+ KB

# %%
value_imports.describe()
# Out:
# Years   2016-2017   2017-2018   2018-2019   2019-2020   2020-2021   2021-2022  \
# count   39.000000   39.000000   39.000000   39.000000   39.000000   39.000000
# mean     7.510256   11.122308   11.166410   13.586667   15.210769   14.977949
# std     29.492733   46.649232   46.054432   51.848247   56.022709   55.544720
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.025000    0.015000    0.050000    0.085000    0.090000    0.095000
# max    167.240000  274.790000  268.600000  297.860000  324.840000  327.930000
#
# Years   2022-2023   2023-2024  2024-2025(Apr-May)
# count   39.000000   39.000000           39.000000
# mean    11.610256   16.468205            1.489744
# std     44.172714   64.354722            4.745580
# min      0.000000    0.000000            0.000000
# ...

# %% [markdown]
# Here we can see that the average imports have seen a steady rise since 2020-21 when Taliban took control of Afghanistan. The highest average imports were seen in the year 2023-24 of about \\$16.05 million.

# %%
# Average Import value
value_imports.T.mean()
# Out:
# Commodity
# DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDIBLE PROD. OF ANIMAL ORIGIN, NOT ELSEWHERE SPEC. OR INCLUDED.                                                    0.001111
# EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.                                                                                                              21.265556
# EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR MELONS.                                                                                                      254.675556
# COFFEE, TEA, MATE AND SPICES.                                                                                                                                36.392222
# PRODUCTS OF THE MILLING INDUSTRY; MALT; STARCHES; INULIN; WHEAT GLUTEN.                                                                                       2.481111
# ...

# %%
# Describing the data of quantity of Imports from Afghanistan
quantity_imports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDIBLE PROD. OF ANIMAL ORIGIN, NOT ELSEWHERE SPEC. OR INCLUDED.   to PROJECT GOODS; SOME SPECIAL USES.
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   2016-2017           52 non-null     float64
#  1   2017-2018           52 non-null     float64
#  2   2018-2019           52 non-null     float64
#  3   2019-2020           52 non-null     float64
#  4   2020-2021           52 non-null     float64
#  5   2021-2022           52 non-null     float64
#  6   2022-2023           52 non-null     float64
#  7   2023-2024           52 non-null     float64
#  8   2024-2025(Apr-May)  52 non-null     float64
# dtypes: float64(9)
# memory usage: 4.1+ KB

# %%
quantity_imports.describe()
# Out:
# Years     2016-2017     2017-2018     2018-2019     2019-2020     2020-2021  \
# count     52.000000     52.000000     52.000000     52.000000     52.000000
# mean    1035.488077   1295.553654   1554.250000   2781.204808   2665.905577
# std     4825.954582   6474.375471   7393.603259  12691.167694  12694.603007
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.060000      0.082500      0.927500      3.315000      1.210000
# max    32400.060000  45205.720000  48977.750000  72139.270000  84339.330000
#
# Years     2021-2022     2022-2023      2023-2024  2024-2025(Apr-May)
# count     52.000000     52.000000      52.000000           52.000000
# mean    2480.464423   1665.929615    3479.744808          237.962692
# std    11128.047606   8483.457339   17409.982425          986.146432
# ...

# %%
# Average Import Quantity
quantity_imports.T.mean()
# Out:
# Commodity
# DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDIBLE PROD. OF ANIMAL ORIGIN, NOT ELSEWHERE SPEC. OR INCLUDED.                                                      0.255556
# LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND THE LIKE; CUT FLOWERS AND ORNAMENTAL FOLIAGE.                                                                     0.122222
# EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.                                                                                                             29010.292222
# EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR MELONS.                                                                                                      57493.356667
# COFFEE, TEA, MATE AND SPICES.                                                                                                                                3637.377778
# ...

# %%
# Plotting the graph of the table in parts
value_imports_1 = value_imports.iloc[:20].T
value_imports_2 = value_imports.iloc[20:].T

# %%
value_imports_1
# Out:
# Commodity           DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDIBLE PROD. OF ANIMAL ORIGIN, NOT ELSEWHERE SPEC. OR INCLUDED.    \
# Years
# 2016-2017                                                        0.00
# 2017-2018                                                        0.00
# 2018-2019                                                        0.00
# 2019-2020                                                        0.00
# 2020-2021                                                        0.00
# 2021-2022                                                        0.00
# 2022-2023                                                        0.00
# 2023-2024                                                        0.01
# 2024-2025(Apr-May)                                               0.00
#
# Commodity           EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.    \
# Years
# 2016-2017                                                       12.32
# ...

# %%
value_imports_2
# Out:
# Commodity           ARTICLES OF APPAREL AND CLOTHING ACCESSORIES, KNITTED OR CORCHETED.    \
# Years
# 2016-2017                                                        0.00
# 2017-2018                                                        0.00
# 2018-2019                                                        0.00
# 2019-2020                                                        0.01
# 2020-2021                                                        0.00
# 2021-2022                                                        0.00
# 2022-2023                                                        0.00
# 2023-2024                                                        0.00
# 2024-2025(Apr-May)                                               0.00
#
# Commodity           ARTICLES OF APPAREL AND CLOTHING ACCESSORIES, NOT KNITTED OR CROCHETED.    \
# Years
# 2016-2017                                                        0.00
# ...

# %%
# Plotting the line plots as subplots
fig, (ax0, ax1) = plt.subplots(nrows = 2, 
                               ncols = 1, 
                               figsize = (30, 35))

ax0.plot(value_imports_1.index,
        value_imports_1);
ax1.plot(value_imports_2.index,
        value_imports_2)

ax0.set(title = "Plotting the Value of Imports to Afghanistan for the first 20 commodities",
        xlabel = "Years",
        ylabel = "Value of Imports in Millions ($)")
ax0.legend(value_imports_1, loc = "upper left", bbox_to_anchor=(1, 1));

ax1.set(title = "Plotting the Value of Imports to Afghanistan for the second 20 commodities",
        xlabel = "Years",
        ylabel = "Value of Imports in Millions ($)")
ax1.legend(value_imports_2, loc = "upper left", bbox_to_anchor=(1, 1));

fig.suptitle('India-Afghanistan Commodity-wise Imports Analysis', 
             fontsize=30, 
             fontweight='bold');

# %% [markdown]
# Here we can see that products like edible vegetables (highest being \\$51 million in 2023-24), fruits (highest being \\$380 million in 2023-24), oil seeds and olea (\\$130 million in 2019-20), and tea and coffee (highest being \\$61 million in 2023-24) are some of the major imports of India from Afghanistan.

# %%
# Plotting the graph of the table in parts
quantity_imports_1 = quantity_imports.iloc[:20].T
quantity_imports_2 = quantity_imports.iloc[20:].T

# %%
quantity_imports_1
# Out:
# Commodity           DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDIBLE PROD. OF ANIMAL ORIGIN, NOT ELSEWHERE SPEC. OR INCLUDED.    \
# Years
# 2016-2017                                                        0.00
# 2017-2018                                                        0.00
# 2018-2019                                                        0.10
# 2019-2020                                                        0.00
# 2020-2021                                                        0.00
# 2021-2022                                                        0.00
# 2022-2023                                                        1.01
# 2023-2024                                                        1.19
# 2024-2025(Apr-May)                                               0.00
#
# Commodity           LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND THE LIKE; CUT FLOWERS AND ORNAMENTAL FOLIAGE.    \
# Years
# 2016-2017                                                         0.0
# ...

# %%
quantity_imports_2
# Out:
# Commodity           MANUFACTURES OF STRAW, OF ESPARTO OR OF OTHER PLAITING MATERIALS; BASKETWARE AND WICKERWORK.    \
# Years
# 2016-2017                                                         0.0
# 2017-2018                                                         0.0
# 2018-2019                                                         0.0
# 2019-2020                                                         0.1
# 2020-2021                                                         0.0
# 2021-2022                                                         0.0
# 2022-2023                                                         0.0
# 2023-2024                                                         0.0
# 2024-2025(Apr-May)                                                0.0
#
# Commodity           PRINTED BOOKDS, NEWSPAPERS, PICTURES AND OTHER PRODUCTS OF THE PRINTING INDUSTRY; MANUSCRIPTS, TYPESCRIPTS AND PLANS.    \
# Years
# ...

# %%
# Plotting the line plots as subplots
fig, (ax0, ax1) = plt.subplots(nrows = 2, 
                               ncols = 1, 
                               figsize = (30, 35))

ax0.plot(quantity_imports_1.index,
        quantity_imports_1);
ax1.plot(quantity_imports_2.index,
        quantity_imports_2)

ax0.set(title = "Plotting the Quantity of Imports to Afghanistan for the first 20 commodities",
        xlabel = "Years",
        ylabel = "Quantity of Imports in Millions ($)")
ax0.legend(quantity_imports_1, loc = "upper left", bbox_to_anchor=(1, 1));

ax1.set(title = "Plotting the Quantity of Imports to Afghanistan for the second 20 commodities",
        xlabel = "Years",
        ylabel = "Quantity of Imports in Millions ($)")
ax1.legend(quantity_imports_2, loc = "upper left", bbox_to_anchor=(1, 1));

fig.suptitle('India-Afghanistan Commodity-wise Imports Analysis', 
             fontsize=30, 
             fontweight='bold');

# %% [markdown]
# Here we can see the major imports from Afghanistan in terms of the quantity of items are: edible fruits (highest being 116 thousand units), edible vegetables (highest at 48 thousand units), wool hair and woven fabric (highest at 249 thousand units in 2019-20) and oil seeds and olea fruits (highest at 10 thousand million at 2020-21).

# %%
# Now removing the commodities with 0 values
value_imports = value_imports.replace(0, np.nan)
value_imports = value_imports.dropna(how = "any", axis = 0)
value_imports
# Out:
# Years                                               2016-2017  2017-2018  \
# Commodity
# EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.         12.32      10.74
# EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR ...     167.24     274.79
# COFFEE, TEA, MATE AND SPICES.                           26.06      33.66
# OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEEDS...       6.69       8.90
# LAC; GUMS, RESINS AND OTHER VEGETABLE SAPS AND ...      80.05     103.33
# NATURAL OR CULTURED PEARLS,PRECIOUS OR SEMIPREC...       0.03       0.08
#
# Years                                               2018-2019  2019-2020  \
# Commodity
# EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.         12.38      39.33
# EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR ...     268.60     297.86
# COFFEE, TEA, MATE AND SPICES.                           35.48      42.33
# OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEEDS...     108.78     130.69
# ...

# %%
len(value_imports)
# Out:
# 6

# %%
# Plotting the remaining commodity graph
plt.figure(figsize = (15, 10))
plt.plot(value_imports.T.index, value_imports.T.iloc[:]);
plt.xlabel("Years")
plt.ylabel("Value of Imports")
plt.title("Value of Imports to Afghanistan")
plt.grid()
plt.legend(value_imports.T.columns, loc = "upper left", bbox_to_anchor=(1, 1))
plt.show();

# %% [markdown]
# Here we can see the major import commodities are edible fruits, edible vegetables, lac, gums and resins and coffee and tea etc.

# %%
# Similarly Plotting the Quantity of the commodities without 0 values
quantity_imports = quantity_imports.replace(0, np.nan)
quantity_imports = quantity_imports.dropna(how = "any", axis = 0)
quantity_imports
# Out:
# Years                                               2016-2017  2017-2018  \
# Commodity
# EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.      12804.76   11967.00
# EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR ...   32400.06   45205.72
# COFFEE, TEA, MATE AND SPICES.                         2778.02    3264.39
# OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEEDS...    4588.66    5092.03
# LAC; GUMS, RESINS AND OTHER VEGETABLE SAPS AND ...     996.18    1200.59
# NATURAL OR CULTURED PEARLS,PRECIOUS OR SEMIPREC...       0.01       0.06
#
# Years                                               2018-2019  2019-2020  \
# Commodity
# EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.      21893.71   72139.27
# EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR ...   48977.75   57619.93
# COFFEE, TEA, MATE AND SPICES.                         3054.20    3934.92
# OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEEDS...    4923.80    8615.75
# ...

# %%
len(quantity_imports)
# Out:
# 6

# %%
# Plotting the remaining commodity graph
plt.figure(figsize = (15, 10))
plt.plot(quantity_imports.T.index, quantity_imports.T.iloc[:]);
plt.xlabel("Years")
plt.ylabel("Quantity of Imports")
plt.title("Quantity of Imports to Afghanistan")
plt.grid()
plt.legend(quantity_imports.T.columns, loc = "upper left", bbox_to_anchor=(1, 1))
plt.show();

# %% [markdown]
# Here too we see the top imports are edible fruits, vegetables and oil seeds and olea fruits etc.
